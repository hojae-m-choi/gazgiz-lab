# %%
from extract import extract_text_from_url

text = extract_text_from_url("https://www.greenpostkorea.co.kr/news/articlePrint.html?idxno=216907")

# %%
# !pip install spacy
# !python -m spacy download ko_core_news_lg
# Out:
# Requirement already satisfied: spacy in /Users/joykim/jupyter/lib/python3.12/site-packages (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy) (2.6.4)
# Requirement already satisfied: jinja2 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy) (3.1.3)
# Requirement already satisfied: setuptools in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy) (69.2.0)
# Requirement already satisfied: packaging>=20.0 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /Users/joykim/jupyter/lib/python3.12/site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/joykim/jupyter/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /Users/joykim/jupyter/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/joykim/jupyter/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/joykim/jupyter/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/joykim/jupyter/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/joykim/jupyter/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/joykim/jupyter/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/joykim/jupyter/lib/python3.12/site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/joykim/jupyter/lib/python3.12/site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/joykim/jupyter/lib/python3.12/site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/joykim/jupyter/lib/python3.12/site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/joykim/jupyter/lib/python3.12/site-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /Users/joykim/jupyter/lib/python3.12/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.1.0)
# Collecting ko-core-news-lg==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ko_core_news_lg-3.7.0/ko_core_news_lg-3.7.0-py3-none-any.whl (230.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 230.9/230.9 MB 21.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /Users/joykim/jupyter/lib/python3.12/site-packages (from ko-core-news-lg==3.7.0) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->ko-core-news-lg==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->ko-core-news-lg==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->ko-core-news-lg==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->ko-core-news-lg==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->ko-core-news-lg==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->ko-core-news-lg==3.7.0) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->ko-core-news-lg==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->ko-core-news-lg==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->ko-core-news-lg==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->ko-core-news-lg==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->ko-core-news-lg==3.7.0) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->ko-core-news-lg==3.7.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->ko-core-news-lg==3.7.0) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->ko-core-news-lg==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->ko-core-news-lg==3.7.0) (2.6.4)
# Requirement already satisfied: jinja2 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->ko-core-news-lg==3.7.0) (3.1.3)
# Requirement already satisfied: setuptools in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->ko-core-news-lg==3.7.0) (69.2.0)
# Requirement already satisfied: packaging>=20.0 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->ko-core-news-lg==3.7.0) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->ko-core-news-lg==3.7.0) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/joykim/jupyter/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->ko-core-news-lg==3.7.0) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /Users/joykim/jupyter/lib/python3.12/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->ko-core-news-lg==3.7.0) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/joykim/jupyter/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->ko-core-news-lg==3.7.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /Users/joykim/jupyter/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->ko-core-news-lg==3.7.0) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/joykim/jupyter/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->ko-core-news-lg==3.7.0) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/joykim/jupyter/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->ko-core-news-lg==3.7.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/joykim/jupyter/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->ko-core-news-lg==3.7.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/joykim/jupyter/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->ko-core-news-lg==3.7.0) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/joykim/jupyter/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->ko-core-news-lg==3.7.0) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/joykim/jupyter/lib/python3.12/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->ko-core-news-lg==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/joykim/jupyter/lib/python3.12/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->ko-core-news-lg==3.7.0) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/joykim/jupyter/lib/python3.12/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->ko-core-news-lg==3.7.0) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/joykim/jupyter/lib/python3.12/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->ko-core-news-lg==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/joykim/jupyter/lib/python3.12/site-packages (from jinja2->spacy<3.8.0,>=3.7.0->ko-core-news-lg==3.7.0) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /Users/joykim/jupyter/lib/python3.12/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->ko-core-news-lg==3.7.0) (1.1.0)
# Installing collected packages: ko-core-news-lg
# Successfully installed ko-core-news-lg-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('ko_core_news_lg')

# %%
import spacy
from rdflib import Graph, URIRef, Literal, Namespace
from rdflib.namespace import RDF, FOAF

# spaCy 모델 로드
nlp = spacy.load("ko_core_news_lg")

# 텍스트 처리
doc = nlp(text)

# RDF 그래프 초기화
g = Graph()

# 네임스페이스 정의 - FIXME - 기사별로 고유 아이디를 부여할것인지...?
n = Namespace("http://example.org/news/")

# 엔티티를 RDF 그래프에 추가 - TODO
for ent in doc.ents:
    print(f"{ent.text}: {ent.label_}")
# Out:
# SKT: OG
# 임호동: PS
# 2024.04.01 17:01: QT
# 4월 14일까지: DT
# 3개월간: DT
# 10개: QT
# SK텔레콤: OG
# SK텔레콤: OG
# SK텔레콤: OG
# SKT: OG
# SKT는: OG
# SK그룹의: OG
# 1일: DT
# SKT와: OG
# SK하이닉스: OG
# SK㈜C&C: OG
# SK브로드밴드: OG
# SK플래닛: OG
# SK ICT패밀리사: OG
# Developer Relations: OG
# SKT는: OG
# 한 걸음: QT
# SKT는: OG
# 4월 1일부터: DT
# 14일까지: DT
# 4월부터: DT
# 7월까지: DT
# 3개월 동안: DT
# 10개의: QT
# SKT는: OG
# 안정환: PS
# SKT: OG
# CHRO: OG
# SK ICT패밀리: OG
# SKT는: OG
# 임호동: PS
# hdlim@greenpost.kr: QT
# ©: OG
# 그린포스트코리아: OG
