# %%
from extract import extract_text_from_url

text = extract_text_from_url("https://www.yna.co.kr/view/AKR20240401030100017?input=1195m")

# %%
# !pip install spacy
# !python -m spacy download ko_core_news_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 20.5 MB/s eta 0:00:0000:0100:01
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('ko_core_news_sm')

# %%
import spacy
from rdflib import Graph, URIRef, Literal, Namespace
from rdflib.namespace import RDF, FOAF

# spaCy 모델 로드
nlp = spacy.load("ko_core_news_sm")

# 텍스트 처리
doc = nlp(text)

# RDF 그래프 초기화
g = Graph()

# 네임스페이스 정의 - FIXME - 기사별로 고유 아이디를 부여할것인지...?
n = Namespace("http://example.org/news/")

# 엔티티를 RDF 그래프에 추가 - TODO
for ent in doc.ents:
    print(ent.label_)
# Out:
# PS
# QT
# OG
# OG
# OG
# PS
# OG
# LC
# LC
# OG
# LC
# LC
# LC
# LC
# LC
# LC
# LC
# LC
# LC
# LC
# LC
# LC
# OG
# OG
# LC
# LC
# LC
# LC
# LC
# LC
# PS
# OG
# OG
# PS
# OG
# OG
# PS
# PS
# DT
# OG
# OG
# PS
# QT
# QT
# QT
# QT
# QT
# QT
# QT
# QT
# QT
# QT
# QT
# QT
# QT
# QT
# LC
# OG
# OG
# DT
# DT
# OG
# OG
# OG
# DT
# OG
# DT
# QT
# PS
# OG
# PS
# OG
# QT
# OG
# LC
# TI
# LC
# QT
# TI
# QT
# QT
# QT
# LC
# LC
# QT
# OG
# LC
# QT
# QT
# PS
# PS
# DT
# PS
# QT
# QT
# TI
# QT
# QT
# QT
# PS
# QT
# DT
# QT
# QT
# QT
# QT
# OG
# DT
# QT
# QT
# OG
# QT
# QT
# QT
# QT
# PS
# QT
# QT
# TI
# QT
# OG
# QT
# QT
# LC
# QT
# QT
# QT
# DT
# DT
# LC
# PS
# PS
# DT
# OG
# OG
# LC
# QT
# QT
# PS
# PS
# DT
# PS
# OG
# PS
# OG
# LC
# TI
# PS
# PS
# OG
# QT
# OG
# LC
# QT
# OG
# QT
# QT
# QT
# QT
# OG
# DT
# OG
# DT
# OG
# LC
# LC
# LC
# OG
# OG
# OG
# LC
# OG
# PS
# LC
# OG
# OG
# OG
# OG
# PS
# OG
# PS
# OG
# LC
# QT
# DT
# DT
# DT
# PS
# OG
